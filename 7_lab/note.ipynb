# %% [markdown]
# # Робота з requests
# ## Робота в середовищі

# %% [markdown]
# # Pipenv

# %%
pipenv --python 3.13
pipenv install jikanpy-v4 Flask
pipenv graph

pipenv install
pipenv shell
python ../anime.py
deactivate

pipenv install flake8 --dev
pipenv --rm
pipenv install --dev
pipenv shell
flake8 ../anime.py 
deactivate

pipenv check --scan

# %%
pipenv --python 3.13
pipenv install jikanpy-v4 Flask
pipenv graph

pipenv install
pipenv shell
python ../anime.py
deactivate

pipenv install flake8 --dev
pipenv --rm
pipenv install --dev
pipenv shell
flake8 ../anime.py 
deactivate

pipenv check --scan

# %% [markdown]
# # Poetry
# - poetry add jikanpy-v4 Flask
# - poetry show --tree
# - poetry install

# %% [markdown]
# # Cтворюємо документацію за допомогою MkDocs

# %%
poetry env remove --all
poetry install --only docs
eval $(poetry env activate)
mkdocs new ./
mkdocs serve

# %% [markdown]
# - за допомогою поетрі створити проект створити додаткову секцію тестування і в цій секції інсталювати пакет pytests
